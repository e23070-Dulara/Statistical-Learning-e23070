# %% [markdown]
# <a href="https://colab.research.google.com/github/e23070-Dulara/Statistical-Learning-e23070/blob/main/Copy_of_max_entropy_inference_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q. Statistical Mechanics of the Quantum Oscillator

# %% [markdown]
# Consider a single quantum harmonic oscillator of angular frequency $\omega$ in thermal equilibrium with a heat bath at temperature $T$. The quantum mechanical energy eigenvalues are given by:
#
# $$E_j = \hbar \omega \left(j + \frac{1}{2}\right), \quad \text{for } j = 0, 1, 2, \dots$$
#
# where $\hbar$ is the reduced Planck constant and $k_B$ is the Boltzmann constant.
#
# **Answer the Following:**
#
# 1. **The Partition Function:**
# Show that the canonical partition function $Z(T) = \sum_{j=0}^\infty e^{-E_j / (k_B T)}$ forms a convergent geometric series that simplifies to:
#
# $$Z(T) = \frac{e^{-\frac{\hbar \omega}{2k_BT}}}{1 - e^{-\frac{\hbar \omega}{k_BT}}}$$
#
#
# 2. **Thermodynamic Potentials:**
# Using your expression for $Z(T)$, derive explicit formulas for:
# * The **Helmholtz Free Energy**, $F(T) = -k_B T \ln Z$.
# * The **Internal Energy**, $U(T) = -\frac{\partial \ln Z}{\partial \beta}$ (where $\beta = \frac{1}{k_B T}$).
#
#
# 3. **Entropy:**
# Find the **Entropy** $S(T)$ of the system using the thermodynamic relation $S = -\left(\frac{\partial F}{\partial T}\right)$, and verify that your result satisfies $U = F + TS$.
# 4. **Heat Capacity and Hyperbolic Form:**
# * Calculate the constant-volume **Heat Capacity**, $C_V = \left(\frac{\partial U}{\partial T}\right)$.
# * Use the hyperbolic identity $\sinh(x) = \frac{e^x - e^{-x}}{2}$ to prove that your expression for $C_V$ can be compactly rewritten as:
#
# $$C_V = k_B \left(\frac{\hbar \omega}{2k_BT}\right)^2 \frac{1}{\sinh^2\left(\frac{\hbar \omega}{2k_BT}\right)}$$
#
#
#
#
# 5. **Asymptotic Behavior (Discussion):**
# Briefly describe the behavior of the heat capacity $C_V$ in the high-temperature limit ($k_B T \gg \hbar \omega$). Does it match the classical equipartition theorem prediction?

# %% [markdown]
# Consider a quantum harmonic oscillator with energy levels
#
# E
# j
# 	​
#
# =ℏω(j+
# 2
# 1
# 	​
#
# ),j=0,1,2,…
#
# where:
#
# ℏ is the reduced Planck constant,
# ω is the angular frequency,
# k
# B
# 	​
#
#  is the Boltzmann constant,
# T is the absolute temperature.
#
# The oscillator is assumed to be in thermal equilibrium with a heat bath, so its thermodynamic properties can be obtained using the canonical ensemble.
#
# 1. Partition Function
#
# The canonical partition function is defined as
#
# Z(T)=
# j=0
# ∑
# ∞
# 	​
#
# e
# −E
# j
# 	​
#
# /(k
# B
# 	​
#
# T)
# .
#
# Substituting the energy eigenvalues,
#
# Z(T)=
# j=0
# ∑
# ∞
# 	​
#
# e
# −
# k
# B
# 	​
#
# T
# ℏω(j+
# 2
# 1
# 	​
#
# )
# 	​
#
# .
#
# Separating the constant term,
#
# Z(T)=e
# −
# 2k
# B
# 	​
#
# T
# ℏω
# 	​
#
# j=0
# ∑
# ∞
# 	​
#
# (e
# −
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# )
# j
# .
#
# The summation is a geometric series with common ratio
#
# r=e
# −
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# ,
#
# where 0<r<1. Since the ratio is less than one, the series converges.
#
# Using the geometric series formula,
#
# j=0
# ∑
# ∞
# 	​
#
# r
# j
# =
# 1−r
# 1
# 	​
#
# ,
#
# we obtain
#
# Z(T)=
# 1−e
# −
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# e
# −
# 2k
# B
# 	​
#
# T
# ℏω
# 	​
#
# 	​
#
# 	​
#
# .
# 2. Thermodynamic Potentials
# (a) Helmholtz Free Energy
#
# The Helmholtz free energy is
#
# F=−k
# B
# 	​
#
# TlnZ.
#
# Taking the logarithm of the partition function,
#
# lnZ=−
# 2k
# B
# 	​
#
# T
# ℏω
# 	​
#
# −ln(1−e
# −
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# ).
#
# Therefore,
#
# F(T)=
# 2
# ℏω
# 	​
#
# +k
# B
# 	​
#
# Tln(1−e
# −
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# )
# 	​
#
# .
#
# This quantity represents the amount of useful work obtainable from the system at temperature T.
#
# (b) Internal Energy
#
# Using
#
# β=
# k
# B
# 	​
#
# T
# 1
# 	​
#
# ,
#
# the internal energy is
#
# U=−
# ∂β
# ∂lnZ
# 	​
#
# .
#
# Since
#
# lnZ=−
# 2
# βℏω
# 	​
#
# −ln(1−e
# −βℏω
# ),
#
# differentiate with respect to β:
#
# ∂β
# ∂lnZ
# 	​
#
# =−
# 2
# ℏω
# 	​
#
# −
# 1−e
# −βℏω
# ℏωe
# −βℏω
# 	​
#
# .
#
# Hence,
#
# U(T)=
# 2
# ℏω
# 	​
#
# +
# e
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# −1
# ℏω
# 	​
#
# 	​
#
# .
#
# The first term is the zero-point energy, while the second term represents the thermal energy due to excited quantum states.
#
# 3. Entropy
#
# The entropy is obtained from
#
# S=−(
# ∂T
# ∂F
# 	​
#
# ).
#
# Differentiating the free energy gives
#
# S=k
# B
# 	​
#
# [
# e
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# −1
# ℏω/k
# B
# 	​
#
# T
# 	​
#
# −ln(1−e
# −
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# )].
# 	​
#
#
# To verify the thermodynamic identity,
#
# U=F+TS,
#
# substitute the expressions for F and S. After simplification, the result becomes
#
# U=
# 2
# ℏω
# 	​
#
# +
# e
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# −1
# ℏω
# 	​
#
# ,
# 	​
#
#
# which is exactly the internal energy obtained earlier. Therefore, the relation
#
# U=F+TS
# 	​
#
#
# is satisfied.
#
# 4. Heat Capacity
#
# The constant-volume heat capacity is
#
# C
# V
# 	​
#
# =(
# ∂T
# ∂U
# 	​
#
# ).
#
# Differentiating the internal energy gives
#
# C
# V
# 	​
#
# =k
# B
# 	​
#
# (
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# )
# 2
# (e
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# −1)
# 2
# e
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# 	​
#
# .
# 	​
#
#
# This expression shows how the energy changes with temperature.
#
# 5. Hyperbolic Form of the Heat Capacity
#
# Using the identity
#
# sinh(x)=
# 2
# e
# x
# −e
# −x
# 	​
#
# ,
#
# let
#
# x=
# 2k
# B
# 	​
#
# T
# ℏω
# 	​
#
# .
#
# Then
#
# (e
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# −1)
# 2
# e
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# 	​
#
# =
# 4sinh
# 2
# (x)
# 1
# 	​
#
# .
#
# Substituting into the previous expression,
#
# C
# V
# 	​
#
# =k
# B
# 	​
#
# (
# 2k
# B
# 	​
#
# T
# ℏω
# 	​
#
# )
# 2
# sinh
# 2
# (
# 2k
# B
# 	​
#
# T
# ℏω
# 	​
#
# )
# 1
# 	​
#
# .
# 	​
#
#
# This compact form is widely used because it is mathematically elegant and convenient for theoretical analysis.
#
# 6. Asymptotic Behaviour of the Heat Capacity
# High-Temperature Limit
#
# When
#
# k
# B
# 	​
#
# T≫ℏω,
#
# the exponential term can be approximated by
#
# e
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# ≈1+
# k
# B
# 	​
#
# T
# ℏω
# 	​
#
# .
#
# Substituting this approximation into the heat capacity expression,
#
# C
# V
# 	​
#
# ≈k
# B
# 	​
#
# .
#
# Therefore,
#
# T→∞
# lim
# 	​
#
# C
# V
# 	​
#
# =k
# B
# 	​
#
# .
# 	​
#
#
# This agrees exactly with the classical equipartition theorem, which states that each harmonic oscillator contributes an average energy of k
# B
# 	​
#
# T, resulting in a heat capacity of k
# B
# 	​
#
# .
#
# Physical Interpretation
#
# At very low temperatures, the oscillator remains mostly in its ground state, so very little energy can be absorbed and the heat capacity approaches zero. As the temperature increases, higher energy levels become populated, causing the heat capacity to rise. In the high-temperature limit, quantum effects become negligible, and the oscillator behaves like a classical system with
#
# C
# V
# 	​
#
# =k
# B
# 	​
#
# ,
# 	​
#
#
# which is consistent with classical statistical mechanics.

# %% [markdown]
# # Q. The Maximum Entropy Distribution under Mean and Variance Constraints

# %% [markdown]
# Consider the random variable $X \in (-\infty, \infty)$. Let:
#
# 1. **The Mean:** $\mathbb{E}[X] = \mu$
# 2. **The Variance:** $\mathbb{E}[(X-\mu)^2] = \sigma^2$
#
# Show that the law of $X$ that maximizes entropy is given by:
#
# $$X \sim \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left( -\frac{(x - \mu)^2}{2\sigma^2} \right)$$

# %% [markdown]
# Let X be a continuous random variable defined over the interval
#
# X∈(−∞,∞),
#
# with the following known properties:
#
# Mean:
# E[X]=μ,
# Variance:
# E[(X−μ)
# 2
# ]=σ
# 2
# .
#
# Our objective is to determine the probability distribution that maximizes the entropy while satisfying these two constraints.
#
# Entropy measures the uncertainty or randomness of a probability distribution. According to the Maximum Entropy Principle, among all distributions having the same mean and variance, the one with the largest entropy makes the fewest assumptions beyond the information already provided.
#
# 1. Entropy of a Continuous Random Variable
#
# The differential entropy of a continuous random variable with probability density function f(x) is
#
# H(X)=−∫
# −∞
# ∞
# 	​
#
# f(x)lnf(x)dx.
#
# We wish to maximize H(X) subject to the following constraints:
#
# The probability density integrates to one:
# ∫
# −∞
# ∞
# 	​
#
# f(x)dx=1.
# The mean is fixed:
# ∫
# −∞
# ∞
# 	​
#
# xf(x)dx=μ.
# The variance is fixed:
# ∫
# −∞
# ∞
# 	​
#
# (x−μ)
# 2
# f(x)dx=σ
# 2
# .
# 2. Applying the Maximum Entropy Principle
#
# Using the method of Lagrange multipliers, we maximize the entropy while enforcing the three constraints.
#
# The Lagrangian is
#
# L=
# 	​
#
# −∫f(x)lnf(x)dx
# +λ
# 0
# 	​
#
# (∫f(x)dx−1)
# +λ
# 1
# 	​
#
# (∫xf(x)dx−μ)
# +λ
# 2
# 	​
#
# (∫(x−μ)
# 2
# f(x)dx−σ
# 2
# ).
# 	​
#
#
# Differentiating with respect to f(x) and setting the result equal to zero gives
#
# −lnf(x)−1+λ
# 0
# 	​
#
# +λ
# 1
# 	​
#
# x+λ
# 2
# 	​
#
# (x−μ)
# 2
# =0.
#
# Rearranging,
#
# lnf(x)=C−λ
# 1
# 	​
#
# x−λ
# 2
# 	​
#
# (x−μ)
# 2
# ,
#
# where C is a constant.
#
# Taking the exponential of both sides,
#
# f(x)=Ae
# −λ
# 1
# 	​
#
# x−λ
# 2
# 	​
#
# (x−μ)
# 2
# ,
#
# where A=e
# C
# .
#
# Using the mean and variance constraints, the constants are determined as
#
# λ
# 1
# 	​
#
# =0,
#
# and
#
# λ
# 2
# 	​
#
# =
# 2σ
# 2
# 1
# 	​
#
# .
#
# The normalization constant becomes
#
# A=
# 2πσ
# 2
# 	​
#
# 1
# 	​
#
# .
#
# Therefore, the probability density function is
#
# f(x)=
# 2πσ
# 2
# 	​
#
# 1
# 	​
#
# exp(−
# 2σ
# 2
# (x−μ)
# 2
# 	​
#
# ).
# 	​
#
#
# This is exactly the probability density function of a normal (Gaussian) distribution.
#
# Hence,
#
# X∼N(μ,σ
# 2
# ).
# 	​

# %% [markdown]
# # Q. Multiclass Logistic Regression: Automatic Classification of Emails

# %% [markdown]
# An e-commerce platform automatically routes inbound customer support emails to one of four mutually exclusive target destinations ($Y$):
#
# * $Y = 0$ : **Finance**
# * $Y = 1$ : **Technical**
#
# Before final classification occurs, an upstream **AI Feature Extractor Agent** processes the raw text of each incoming email and outputs a discrete binary state observation vector $\mathbf{x} = (x_1, x_2, x_3)^T \in \mathscr{X}$, where:
#
# * $x_1 = \mathbb{I}(\text{Financial context detected})$ (e.g., words like *"charge"*, *"invoice"*)
# * $x_2 = \mathbb{I}(\text{Account access context detected})$ (e.g., words like *"password"*, *"login"*)
# * $x_3 = \mathbb{I}(\text{Bug/malfunction context detected})$ (e.g., words like *"error"*, *"frozen"*)
#
# ---
#
# Because human language inherently overlaps, the AI Agent's outputs are distributed non-deterministically across three common operational scenarios. The marginal probability of observing each state is fixed by historical logs to:
#
# 1. **Scenario A (Pure Financial):** $\mathbf{x}_A = (1, 0, 0)^T \implies P(\mathbf{x}_A) = 0.40$
# 2. **Scenario B (Pure Acces):** $\mathbf{x}_B = (0, 1, 0)^T \implies P(\mathbf{x}_B) = 0.25$
# 3. **Scenario C (Pure Technical):** $\mathbf{x}_C = (0, 0, 1)^T \implies P(\mathbf{x}_C) = 0.05$
# 3. **Scenario D (Access Technical):** $\mathbf{x}_D = (0, 1, 1)^T \implies P(\mathbf{x}_D) = 0.15$
# 3. **Scenario E (Billing Access):** $\mathbf{x}_E = (1, 1, 0)^T \implies P(\mathbf{x}_E) = 0.05$
#
# ---
#
# Historical manual audits provide the following observed joint dataset expectations:
#
# * Constraint 1: $\mathbb{E}[x_1 \cdot \mathbb{I}(Y=1)] = \mathbf{0.05}$
# (Very low. If financial words are present, it is rarely routed to Technical support.)
#
# * Constraint 2: $\mathbb{E}[x_2 \cdot \mathbb{I}(Y=1)] = \mathbf{0.15}$
# (Moderate. Account access issues split down the middle depending on context.)
#
# * Constraint 3: $\mathbb{E}[x_3 \cdot \mathbb{I}(Y=1)] = \mathbf{0.16}$
# (High. If a bug or malfunction context is detected, it goes to the Tech team the vast majority of the time, utilizing $80\%$ of the $0.20$ max capacity).

# %% [markdown]
# The feature vector is
#
# x=(x
# 1
# 	​
#
# ,x
# 2
# 	​
#
# ,x
# 3
# 	​
#
# )
# T
# ,
#
# where
#
# x
# 1
# 	​
#
# =1 if financial-related words (such as charge or invoice) are detected.
# x
# 2
# 	​
#
# =1 if account-access words (such as login or password) are detected.
# x
# 3
# 	​
#
# =1 if technical issue words (such as error or frozen) are detected.
#
# The possible routing decisions are
#
# Y=0: Finance
# Y=1: Technical
# 1. Feature Distribution
#
# Historical customer support data shows that the AI agent most commonly observes the following feature combinations:
#
# Scenario	Feature Vector	Interpretation	Probability
# A	(1,0,0)	Pure Financial issue	0.40
# B	(0,1,0)	Pure Account Access issue	0.25
# C	(0,0,1)	Pure Technical issue	0.05
# D	(0,1,1)	Account Access + Technical issue	0.15
# E	(1,1,0)	Billing + Account Access issue	0.05
#
# These probabilities sum to
#
# 0.40+0.25+0.05+0.15+0.05=1,
#
# confirming that they represent a valid probability distribution.
#
# 2. Interpretation of the Historical Constraints
#
# Historical audits provide information about how often certain features are associated with Technical support.
#
# Constraint 1
# E[x
# 1
# 	​
#
# I(Y=1)]=0.05.
#
# Here,
#
# I(Y=1) equals 1 only when an email is routed to the Technical team.
#
# Therefore,
#
# x
# 1
# 	​
#
# I(Y=1)
#
# is equal to 1 only if
#
# financial keywords are detected, and
# the email is routed to Technical support.
#
# Since the expected value is only
#
# 0.05,
#
# this tells us that emails containing financial keywords are rarely sent to the Technical department. Most of these emails are correctly handled by the Finance team.
#
# Constraint 2
# E[x
# 2
# 	​
#
# I(Y=1)]=0.15.
#
# This measures how often account-access related emails are routed to Technical support.
#
# Because account-access issues can involve either billing or software problems, these emails are divided between Finance and Technical teams.
#
# An expectation of
#
# 0.15
#
# indicates a moderate probability of being routed to Technical support.
#
# Constraint 3
# E[x
# 3
# 	​
#
# I(Y=1)]=0.16.
#
# This measures how frequently bug or malfunction keywords appear in emails routed to Technical support.
#
# The maximum probability of observing
#
# x
# 3
# 	​
#
# =1
#
# is
#
# P(x
# 3
# 	​
#
# =1)=0.05+0.15=0.20.
#
# Since
#
# 0.16=0.80×0.20,
#
# approximately 80% of all emails containing technical problem keywords are assigned to the Technical team.
#
# This is expected because software errors and system malfunctions are primarily handled by technical support engineers.
#
# 3. Maximum Entropy Model
#
# To predict the routing decision while making the fewest assumptions beyond the observed data, the Maximum Entropy Principle is used.
#
# The conditional probability of assigning an email to Technical support is modeled as
#
# P(Y=1∣x)=
# 1+exp(λ
# 1
# 	​
#
# x
# 1
# 	​
#
# +λ
# 2
# 	​
#
# x
# 2
# 	​
#
# +λ
# 3
# 	​
#
# x
# 3
# 	​
#
# )
# exp(λ
# 1
# 	​
#
# x
# 1
# 	​
#
# +λ
# 2
# 	​
#
# x
# 2
# 	​
#
# +λ
# 3
# 	​
#
# x
# 3
# 	​
#
# )
# 	​
#
# .
#
# Similarly,
#
# P(Y=0∣x)=
# 1+exp(λ
# 1
# 	​
#
# x
# 1
# 	​
#
# +λ
# 2
# 	​
#
# x
# 2
# 	​
#
# +λ
# 3
# 	​
#
# x
# 3
# 	​
#
# )
# 1
# 	​
#
# .
#
# The parameters
#
# λ
# 1
# 	​
#
# ,λ
# 2
# 	​
#
# ,λ
# 3
# 	​
#
#
# are selected so that the model satisfies the three historical expectation constraints.
#
# 4. Interpretation of the Model Parameters
#
# The values of the parameters determine how strongly each feature influences the routing decision.
#
# Financial keywords (λ
# 1
# 	​
#
# ) should have a negative weight, since financial emails are rarely routed to Technical support.
# Account-access keywords (λ
# 2
# 	​
#
# ) should have a moderate positive weight, reflecting that these issues may require either Finance or Technical assistance.
# Bug or malfunction keywords (λ
# 3
# 	​
#
# ) should have the largest positive weight, because these emails are most often handled by the Technical team.
#
# Thus,
#
# ∣λ
# 3
# 	​
#
# ∣>∣λ
# 2
# 	​
#
# ∣>∣λ
# 1
# 	​
#
# ∣.

# %% [markdown]
# # Q. Asset Pricing and Portfolio Optimization.

# %% [markdown]
# In standard finance, models often assume asset returns follow a perfect Normal (Gaussian) distribution. However, real-world markets experience extreme events, leading to "fat tails" and skewed returns. MaxEnt allows an analyst to infer the **least-biased probability distribution** of an asset's future price based *only* on what the market currently tells us, without forcing it into a rigid Gaussian shape.
#
# **Background:**
#
# You are a quantitative portfolio manager evaluating a highly volatile tech stock, **Asset X**, currently trading at $\$100$. You want to determine the risk-neutral probability distribution of its price, $S_T$, in exactly one month. This distribution will allow you to correctly price exotic derivatives and optimize your portfolio's risk exposure.
#
# **Available Market Data (The Constraints):**
#
# You do not know the true distribution, but you can observe the following macroeconomic aggregates and market-clearing prices from the options exchange:
#
# 1. **The Risk-Free Growth:** Based on the risk-free interest rate, the expected future price of the asset must match the forward price:
#
# $$\mathbb{E}[S_T] = \$102$$
#
#
# 2. **The Market Volatility:** Based on standard historical variance, the expected squared price is constrained by:
#
# $$\mathbb{E}[S_T^2] = 10,600$$
#
#
# 3. **Asymmetric Market Sentiment (The "Skew"):** Due to heavy trading on out-of-the-money put options, the market is pricing in a strong downside risk. The expected value of a specific logarithmic penalty (which captures downward crash risk) is constrained to:
#
# $$\mathbb{E}[\ln(S_T)] = 4.60$$
#
#
#
# **Objective:**
#
# Formulate and solve the Maximum Entropy problem to find the continuous probability density function $p(S_T)$ for $S_T > 0$.

# %% [markdown]
# Given Market Constraints
#
# The future asset price is denoted by S
# T
# 	​
#
# , where S
# T
# 	​
#
# >0.
#
# From the market, we know the following information:
#
# 1. Expected Future Price
#
# The expected future price equals the forward price implied by the risk-free interest rate:
#
# E[S
# T
# 	​
#
# ]=102.
#
# This ensures that the estimated distribution is consistent with the market's pricing of forward contracts.
#
# 2. Expected Squared Price
#
# The observed market volatility provides the second moment:
#
# E[S
# T
# 2
# 	​
#
# ]=10600.
#
# This constraint controls the spread of the probability distribution and reflects the uncertainty in future prices.
#
# 3. Expected Logarithmic Price
#
# Options markets indicate a strong downside risk, represented by
#
# E[ln(S
# T
# 	​
#
# )]=4.60.
#
# Unlike the first two moments, this logarithmic constraint captures market expectations about asymmetric downside movements and crash risk.
#
# Step 1: Define the Entropy
#
# For a continuous random variable, the differential entropy is
#
# H(p)=−∫
# 0
# ∞
# 	​
#
# p(S
# T
# 	​
#
# )lnp(S
# T
# 	​
#
# )dS
# T
# 	​
#
# .
#
# Our objective is to maximize this entropy.
#
# Maximizing entropy means selecting the probability distribution that is least biased while still satisfying all observed market constraints.
#
# Step 2: Define the Constraints
#
# The probability density must satisfy four conditions.
#
# (i) Normalization
#
# The total probability must equal one.
#
# ∫
# 0
# ∞
# 	​
#
# p(S
# T
# 	​
#
# )dS
# T
# 	​
#
# =1.
# (ii) Mean Constraint
# ∫
# 0
# ∞
# 	​
#
# S
# T
# 	​
#
# p(S
# T
# 	​
#
# )dS
# T
# 	​
#
# =102.
# (iii) Second-Moment Constraint
# ∫
# 0
# ∞
# 	​
#
# S
# T
# 2
# 	​
#
# p(S
# T
# 	​
#
# )dS
# T
# 	​
#
# =10600.
# (iv) Logarithmic Constraint
# ∫
# 0
# ∞
# 	​
#
# ln(S
# T
# 	​
#
# )p(S
# T
# 	​
#
# )dS
# T
# 	​
#
# =4.60.
# Step 3: Construct the Maximum Entropy Problem
#
# Using the method of Lagrange multipliers, the optimization problem becomes
#
# L=
# 	​
#
# −∫p(S
# T
# 	​
#
# )lnp(S
# T
# 	​
#
# )dS
# T
# 	​
#
# +λ
# 0
# 	​
#
# (∫p(S
# T
# 	​
#
# )dS
# T
# 	​
#
# −1)
# +λ
# 1
# 	​
#
# (∫S
# T
# 	​
#
# p(S
# T
# 	​
#
# )dS
# T
# 	​
#
# −102)
# +λ
# 2
# 	​
#
# (∫S
# T
# 2
# 	​
#
# p(S
# T
# 	​
#
# )dS
# T
# 	​
#
# −10600)
# +λ
# 3
# 	​
#
# (∫ln(S
# T
# 	​
#
# )p(S
# T
# 	​
#
# )dS
# T
# 	​
#
# −4.60).
# 	​
#
#
# Differentiating with respect to p(S
# T
# 	​
#
# ) and setting the derivative equal to zero gives
#
# −lnp(S
# T
# 	​
#
# )−1+λ
# 0
# 	​
#
# +λ
# 1
# 	​
#
# S
# T
# 	​
#
# +λ
# 2
# 	​
#
# S
# T
# 2
# 	​
#
# +λ
# 3
# 	​
#
# ln(S
# T
# 	​
#
# )=0.
# Step 4: Obtain the Maximum Entropy Distribution
#
# Rearranging the previous equation,
#
# lnp(S
# T
# 	​
#
# )=C+λ
# 1
# 	​
#
# S
# T
# 	​
#
# +λ
# 2
# 	​
#
# S
# T
# 2
# 	​
#
# +λ
# 3
# 	​
#
# ln(S
# T
# 	​
#
# ),
#
# where C is a constant.
#
# Taking the exponential of both sides,
#
# p(S
# T
# 	​
#
# )=AS
# T
# λ
# 3
# 	​
#
# 	​
#
# exp(λ
# 1
# 	​
#
# S
# T
# 	​
#
# +λ
# 2
# 	​
#
# S
# T
# 2
# 	​
#
# ),
#
# where
#
# A=e
# C
#
# is the normalization constant.
#
# For the density to remain finite and integrable,
#
# λ
# 2
# 	​
#
# <0.
#
# Therefore, the Maximum Entropy probability density is
#
# p(S
# T
# 	​
#
# )=AS
# T
# λ
# 3
# 	​
#
# 	​
#
# exp(λ
# 1
# 	​
#
# S
# T
# 	​
#
# +λ
# 2
# 	​
#
# S
# T
# 2
# 	​
#
# ),S
# T
# 	​
#
# >0.
# 	​
#
#
# The constants
#
# A,λ
# 1
# 	​
#
# ,λ
# 2
# 	​
#
# ,λ
# 3
# 	​
#
#
# are determined numerically so that all four market constraints are satisfied exactly.
